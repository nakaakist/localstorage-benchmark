# %% [markdown]
# # Visualize local storage performance

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.size'] = 14

# %% [markdown]
# PC specs
# - MacBook Air (2020)
# - CPU: Apple M1
# - RAM: 16 GB
# - macOS 14.3
# - Browser: Chrome 123.0.6312.87

# %% [markdown]
# # 1. Large Number of Keys

# %%
d1x = np.array([[0.2,7.450580596923829e-10,7.450580596923829e-10],[15.059999997168777,2.099999997764826,10.71999999806285],[21.779999999701975,3.0599999994039533,19.359999999403954],[29.480000001192092,3.500000000745058,28.640000000596043],[43.12000000029803,4.960000001639128,37.8]])
d4x = np.array([[0.22000000029802322,0.1,0],[23.740000001341105,4.559999999403954,22.160000000894073],[47.539999999850984,8.400000000745058,46.59999999925494],[74.38000000044704,12.979999999701976,71.68000000044704],[101.5199999988079,18.939999997615814,96.83999999910593]])
d6x = np.array([[0.15999999940395354,0.019999999552965164,0.08000000044703484],[33.12000000104308,7.019999999552965,33.18000000119209],[68.49999999850988,19.100000000745055,66.97999999970199],[106.43999999761581,23.499999999254946,102.87999999821186],[147.41999999806285,29.319999999552962,140.15999999940394]])

# %%
num_keys = [1, 2500, 5000, 7500, 10000]

# %%
for idx in range(3):
    plt.figure(figsize=(6,4))
    plt.plot(num_keys, d1x[:, idx], 'o-', label="normal")
    plt.plot(num_keys, d4x[:, idx], 'o-', label="CPU 4x slowdown")
    plt.plot(num_keys, d6x[:, idx], 'o-', label="CPU 6x slowdown")
    plt.legend(loc="best")
    plt.grid()
    plt.xlabel('Number of local storage keys')
    plt.ylabel('Time (ms)')

# %% [markdown]
# # 2. Large Data

# %%
d1x = np.array([[0.060000000149011606,0,0],[2.5000000007450582,2.319999998807907,0.5200000002980232],[4.939999999850988,4.860000000149012,1.0799999989569187],[6.36000000089407,5.960000001639127,1.4]])
d4x = np.array([[0.1799999989569187,0.020000000298023225,0.020000000298023225],[10.339999999850988,9.839999999850988,2.279999999701977],[20.779999998956917,19.5,4.1000000000000005],[26.779999999701978,24.100000001490116,5.1000000000000005]])
d6x = np.array([[0.31999999955296515,0,0.019999999552965164],[15.679999999701977,14.919999999552967,3.039999999850988],[31.359999998658893,29.779999999701978,5.480000000447035],[39,36.480000000447035,7.279999998956919]])

# %%
num_letters = [0, 4, 8, 10]

# %%
for idx in range(3):
    plt.figure(figsize=(6,4))
    plt.plot(num_letters, d1x[:, idx], 'o-', label="normal")
    plt.plot(num_letters, d4x[:, idx], 'o-', label="CPU 4x slowdown")
    plt.plot(num_letters, d6x[:, idx], 'o-', label="CPU 6x slowdown")
    plt.legend(loc="best")
    plt.grid()
    plt.xlabel('Size of local storage data (MB)')
    plt.ylabel('Time (ms)')

# %% [markdown]
# # 3. Large Neighbor Data

# %%
d1x = np.array([[0.020000000298023225,0,0.019999999552965164],[0,0,0],[0,0,0],[0,0,0]])

# %%
num_neighbor_letters = [0, 0.0001, 0.01, 1]

# %%
for idx in range(3):
    plt.figure(figsize=(6,4))
    plt.plot(num_neighbor_letters, d1x[:, idx], 'o-', label="normal")
    plt.legend(loc="best")
    plt.grid()
    plt.xlabel('Size of local storage data (MB)')
    plt.ylabel('Time (ms)')
